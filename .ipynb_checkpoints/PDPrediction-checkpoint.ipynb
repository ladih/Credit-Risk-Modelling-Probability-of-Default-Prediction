# %% [markdown]
# # Credit Risk Modelling: Probability of Default Prediction
#
# Using logistic regression to predict probability of default (PD). Includes variable selection, feature engineering, and evaluation tools such as AUC, KS statistic, PSI, and calibration.
#
# **Programming Language:** Python.
#
# **Data source**: Lending Club loan data, https://www.kaggle.com/datasets/adarshsng/lending-club-loan-data-csv.

# %% [markdown]
# ## 1. Data Preprocessing
#
# A sample of the full dataset was used, consisting of 173,412 loans, each with and 145 features. Features were a mix of numerical, categorical, and text/string.
#
# Example of features: loan status, annual income, debt-to-income ratio.

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score, recall_score
import matplotlib.pyplot as plt

# Load sample dataset
df = pd.read_csv('loan_sample.csv', low_memory=False)

# %% [markdown]
# ### Create Binary Target
#
# Loan statuses "Charged Off" or "Default" were defined as **default** and "Fully Paid" as **non-default**. Other statuses were excluded.
#
# Defaulted loans were encoded as 1, non-defaulted as 0.
#
# 100,000 loans remained after filtering these statuses.

# %%
# Filter statuses
target_statuses = ['Fully Paid', 'Charged Off', 'Default']
df_filtered = df[df['loan_status'].isin(target_statuses)].copy()

# %%
# Encode target
df_filtered['default'] = df_filtered['loan_status'].isin(['Charged Off', 'Default']).astype(int)

# %% [markdown]
# ### Class Distribution

# %%
counts = df_filtered['default'].value_counts()
plt.figure(figsize=(5, 4))
plt.bar(counts.index.astype(str), counts.values, color=['green','red'])
plt.ylabel('Number of Loans')
plt.xlabel('Class (0 = non-default, 1 = default)')
plt.show()

# %% [markdown]
# **Figure 1:** Figure showing clear class imbalance. May impact model performance, particularly threshold-dependent metrics like recall.

# %% [markdown]
# ### Variable Selection
#
# Only variables that were definitely available at the time of loan origination were included in the model. Variables with uncertain availability or other issues (e.g., missing values) were excluded. The resulting set of variables is described below, with definitions taken from LCDataDictionary.xlsx
#
# - **annual_inc**         - The self-reported annual income provided by the borrower during registration
#
# - **application_type**   - Indicates whether the loan is an individual application or a joint application with two co-borrowers
#
# - **dti**                - A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income
#
# - **home_ownership**     - The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
#
# - **purpose**            - A category provided by the borrower for the loan request
#
# Example of variables with uncertain time measurements:
#
# - **delinq_2yrs**   - The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years.
#     *(may have been updated after loan origination)*
#
# - **loan_amnt**    - The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value
#   *(may have been updated after loan origination)*
#
# Extra variables:
#
# - **loan_status** - Current status of the loan
#     *(target variable)*
# - **issue_d** - The month which the loan was funded
#     *(used only for time-based splitting)*

# %%
selected_vars = [
    'annual_inc',
    'application_type',
    'dti',
    'home_ownership',
    'purpose',
    'default',  # target
    'issue_d',  # for time-based splitting
]
df_model = df_filtered[selected_vars].copy()

# %% [markdown]
# ### Description of Numeric Variables

# %%
df_model.describe()
# Out:
#          annual_inc           dti        default
# count  1.000000e+05  99977.000000  100000.000000
# mean   7.598839e+04     18.270974       0.200740
# std    6.724343e+04     10.356567       0.400556
# min    0.000000e+00      0.000000       0.000000
# 25%    4.550000e+04     11.840000       0.000000
# 50%    6.500000e+04     17.610000       0.000000
# 75%    9.000000e+04     24.060000       0.000000
# max    8.900060e+06    999.000000       1.000000

# %% [markdown]
# **Note:** Maximum dti is 999. These unusually high values occur for borrowers with very low reported income (mean = 430 vs. overall mean = 75,989) and were retained.

# %% [markdown]
# ### Missing Values
#
# The only variable with missing values was dti, with 23 (0.02%) missing entries. These values were replaced with the median of dti.

# %%
numeric_cols = df_model.select_dtypes(include=['number']).columns
df_model[numeric_cols] = df_model[numeric_cols].fillna(df_model[numeric_cols].median())

# %% [markdown]
# ### One-Hot Encoding
#
# The categorical features (purpose, home_ownership, and application_type) were one-hot encoded.

# %%
categorical_cols = ['purpose', 'home_ownership', 'application_type']
df_model = pd.get_dummies(df_model, columns=categorical_cols, drop_first=True)

# %% [markdown]
# ### Time-based Train/Test Split
# To prevent data leakage and mimic a real-world scenario, the data was sorted by issue date (issue_d) and split into training (first 80%) and testing (last 20%) sets.

# %%
# Time-based Train/test split
df_sorted = df_model.sort_values('issue_d')

split_point = int(0.8 * len(df_sorted))

X_train = df_sorted.iloc[:split_point].drop(['default', 'issue_d'], axis=1)
y_train = df_sorted.iloc[:split_point]['default']
X_test = df_sorted.iloc[split_point:].drop(['default', 'issue_d'], axis=1)
y_test = df_sorted.iloc[split_point:]['default']

# %% [markdown]
# ### Feature Scaling
#
# After the train/test split the features were scaled so that each had a mean of 0 and a standard deviation of 1. This makes makes the coefficients in logistic regression easier to comparable.

# %%
# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## 2. Model Training
#
# The logistic regression model estimates the probability of default for each observation as
#
# $$
# p(\mathbf{x_1, \dots, x_m}) = \frac{1}{1 + \exp\big(-(\beta_0 + \beta_1 x_1 + \dots + \beta_m x_m)\big)},
# $$
#
# where $x_1, \dots, x_m$ are the input features, and $\beta_0, \dots, \beta_m$ are the coefficients estimated from the training data.
#
# The model was trained using scikit-learn’s LogisticRegression class (with its default L2 regularization).

# %%
# Train model and make predictions
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]
y_pred = (y_pred_proba >= 0.5).astype(int)

# %% [markdown]
# ## 3. Result Metrics

# %% [markdown]
# ### Recall at Threshold = 0.5
#
# At a classification threshold of 0.5, the model correctly classifies 100% of non-defaulters but 0% of defaulters. This is primarily due to the combination of imbalanced class proportions (20% defaults) and the default threshold of 0.5. The class imbalance biases the model toward predicting probabilities near 0, since 0 represents non-defaulters. As a result, the threshold of 0.5 is rarely exceeded, leading to poor recall for defaulters but perfect recall for non-defaulters.
#
# One way to achieve a more balanced recall is to lower the classification threshold. For example, setting the threshold to 0.2 better reflects the underlying class imbalance. At this threshold, the recalls are more balanced: 0.58 for defaulters and 0.56 for non-defaulters.

# %% [markdown]
# ### Threshold Independent Metrics
#
#
# #### AUC and Gini Coefficient
# The AUC (Area Under the ROC Curve) represents the probability that the model assigns a higher predicted probability to a randomly chosen defaulter than to a randomly chosen non-defaulter. A random classifier would do this 50% of the time and hence have an AUC of 0.5. Values closer to 1 indicate better discrimination between the classes.
#
# The Gini coefficient is defined as 2 × AUC − 1. It provides no additional information beyond the AUC but is commonly reported in credit risk practice.
#
# The model achieves an AUC of 0.605 and Gini coefficient of 0.209. The AUC of 0.605 indicates that the model performs better than random guessing, although in credit risk applications, higher values are generally preferred (e.g., >0.7). Using additional relevant features could improve the result.

# %%
# AUC and Gini
auc = roc_auc_score(y_test, y_pred_proba)
gini = 2 * auc - 1

# %% [markdown]
# #### ROC

# %%
# ROC plot
plt.figure(figsize=(6,4))
# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {auc:.3f})')

# plot KS point
ks_index = (tpr - fpr).argmax()
plt.scatter(fpr[ks_index], tpr[ks_index], color='red', s=30, label='KS point', zorder=5)

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')  # random classifier line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# **Figure 2:** ROC curve showing the trade-off between TPR and FPR, with the KS point highlighted.

# %% [markdown]
# #### KS Statistic (Kolmogorov-Smirnov)
#
# The KS statistic represents the maximum separation between the true positive rate (TPR) and false positive rate (FPR) across all thresholds. Values closer to 1 indicate stronger discrimination between the classes, with higher values suggesting the model is better at distinguishing defaulters from non-defaulters.
#
# The model’s KS statistic is 0.156, indicating weak discrimination. This is below typical industry thresholds for moderate separation, suggesting that additional features or model tuning may be needed to improve performance.

# %%
# KS point
ks = max(tpr - fpr)

# %% [markdown]
# ### Stability/Monitoring Metrics
#
# #### PSI (Population Stability Index)
#
# The Population Stability Index (PSI) measures how the distribution of predicted probabilities (or of individual features) changes between the training set and test set (or future/out-of-time samples). Values close to 0 indicate stable distributions, while larger values suggest population drift and potential model degradation. The PSI depends on how the data is partitioned into bins, and different binning strategies may slightly affect the value.
#
# The model's PSI, calculated using 10 uniformly distributed bins, is 0.002. This indicates that the distribution of predicted probabilities is very similar between the training and test sets, suggesting no significant population drift.

# %%
# PSI code details
# Predicted probabilities for the training set
y_pred_proba_train = model.predict_proba(X_train_scaled)[:, 1]

n_bins = 10
bin_edges = np.linspace(0, 1, n_bins + 1)

df_PSI_test = pd.DataFrame({'y_pred_proba': y_pred_proba})

df_PSI_test['bin'] = pd.cut(df_PSI_test['y_pred_proba'], bins=bin_edges, include_lowest=True)

df_test_bins = (
    df_PSI_test.groupby('bin')
    .agg(count=('y_pred_proba', 'count'))
    .reset_index()
)

df_test_bins['fraction_test'] = df_test_bins['count'] / df_test_bins['count'].sum()

df_PSI_train = pd.DataFrame({'y_pred_proba_train': y_pred_proba_train})

df_PSI_train['bin'] = pd.cut(df_PSI_train['y_pred_proba_train'], bins=bin_edges, include_lowest=True)

df_train_bins = (
    df_PSI_train.groupby('bin')
    .agg(count=('y_pred_proba_train', 'count'))
    .reset_index()
)

df_train_bins['fraction_train'] = df_train_bins['count'] / df_train_bins['count'].sum()
# Out:
# C:\Users\ollen\AppData\Local\Temp\ipykernel_6172\4206453536.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_PSI_test.groupby('bin')
# C:\Users\ollen\AppData\Local\Temp\ipykernel_6172\4206453536.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_PSI_train.groupby('bin')

# %%
def calculate_psi(train_frac, test_frac):
    """
    train_frac: array of fractions per bin in the baseline population
    test_frac: array of fractions per bin in the new population
    """
    epsilon = 1e-8  # to avoid division by zero
    psi_values = (train_frac - test_frac) * np.log((train_frac + epsilon) / (test_frac + epsilon))
    return np.sum(psi_values)

psi = calculate_psi(df_train_bins['fraction_train'], df_test_bins['fraction_test'])

# %%
# PSI plot code
plt.figure(figsize=(6, 4))
x_mid = df_test_bins['bin'].apply(lambda x: x.mid).to_numpy()
plt.plot(x_mid, df_train_bins['fraction_train'].to_numpy(), label='Train', marker='o')
plt.plot(x_mid, df_test_bins['fraction_test'].to_numpy(), label='Test', marker='o')

plt.xticks(rotation=45)
plt.xticks(np.arange(0, 1.01, 0.1))  # ticks at 0.0, 0.1, 0.2, ..., 1.0
plt.xlabel("Probability bin")
plt.ylabel("Fraction of samples")
plt.title("Distribution of predicted probabilities (Train vs Test)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 3:** Plot confirming the small PSI values (the training curve is barely visible). The plot also shows that most predicted probabilities lie between 0 and 0.5, reflecting the class imbalance (80% non-defaults).

# %% [markdown]
# ### Calibration

# %%
# Calibration plot code
df_calibration = pd.DataFrame({
    'y_test': y_test,
    'y_pred_proba': y_pred_proba
})

n_bins_cali = 10
bin_edges = np.linspace(0, 1, n_bins_cali + 1)

df_calibration["bin"] = pd.cut(df_calibration['y_pred_proba'], bins=bin_edges, include_lowest=True)
calibration_table = df_calibration.groupby('bin').agg(
    avg_pred=('y_pred_proba', 'mean'),          # Average predicted PD in the bin
    obs_default_rate=('y_test', 'mean'),        # Fraction of defaults in the bin
).reset_index() # make the bins a column instead of index, and use standard index

plt.figure(figsize=(6,4))
plt.plot([0,1], [0,1], 'k--', label='Perfect calibration')
plt.plot(calibration_table['avg_pred'].to_numpy(), calibration_table['obs_default_rate'].to_numpy(), marker='o', label='Model')
plt.xlabel('Average Predicted PD')
plt.ylabel('Observed Default Rate')
plt.title('Calibration Plot')
plt.legend()
plt.show()
# Out:
# C:\Users\ollen\AppData\Local\Temp\ipykernel_6172\3075073517.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   calibration_table = df_calibration.groupby('bin').agg(

# %% [markdown]
# **Figure 4:** Calibration plot: Shows how well predicted probabilities correspond to the actual fraction of defaulters. For example, if the average predicted probability in the bin [0, 0.1] is 0.06, the fraction of actual defaulters in that bin should also be approximately 0.06.
#
# The model is well-calibrated for lower predicted probabilities, where most samples lie (as shown in the probability distribution plot above). At higher probabilities, there are few observations, and due to class imbalance (more non-defaulters), a few high-probability non-defaults can distort the observed fraction of defaulters. This explains the deviation from the diagonal in the high-probability region.

# %% [markdown]
# ### Feature Importance
#
# A positive coefficient indicates that the probability of default increases as the feature value increases, while a negative coefficient indicates that the probability of default decreases. The table below shows the top five most influential features.

# %%
# feature importance code
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Coefficient': model.coef_[0].round(3)
}).sort_values('Coefficient', key=abs, ascending=False)
top_n_features = 5
feature_importance.head(top_n_features)

top_features = feature_importance.head(top_n_features)
top_features.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2791c">
#   <thead>
#     <tr>
#       <th id="T_2791c_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_2791c_level0_col1" class="col_heading level0 col1" >Coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2791c_row0_col0" class="data row0 col0" >purpose_debt_consolidation</td>
#       <td id="T_2791c_row0_col1" class="data row0 col1" >0.321000</td>
#     </tr>
#     <tr>
#       <td id="T_2791c_row1_col0" class="data row1 col0" >dti</td>
#       <td id="T_2791c_row1_col1" class="data row1 col1" >0.261000</td>
#     </tr>
#     <tr>
#       <td id="T_2791c_row2_col0" class="data row2 col0" >purpose_home_improvement</td>
#       <td id="T_2791c_row2_col1" class="data row2 col1" >0.179000</td>
#     </tr>
#     <tr>
#       <td id="T_2791c_row3_col0" class="data row3 col0" >purpose_credit_card</td>
#       <td id="T_2791c_row3_col1" class="data row3 col1" >0.170000</td>
#     </tr>
#     <tr>
#       <td id="T_2791c_row4_col0" class="data row4 col0" >purpose_other</td>
#       <td id="T_2791c_row4_col1" class="data row4 col1" >0.143000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Summary and Potential Improvements
#
# The model achieved an AUC of 0.605, indicating peformance better than random. While the performance is modest, it suggests that the model may have some practical applications.
#
# A clear disadvantage of the model is that it relied on only 5 of the 144 available features. If the availability of features at loan origination was more clear, more features could have been used, possibly improving the performance.
#
# Other potential improvements:
# - Exploring other models, such as tree based classifiers or neural networks.
# - Noise reduction and quantitative variable selection to focus on the most informative features.

# %% [markdown]
# ## Appendix: Full Python Code
#
# ```python
# # Using Lending Club Loan Data,
# # https://www.kaggle.com/datasets/adarshsng/lending-club-loan-data-csv
#
# # Import libraries
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import roc_curve, roc_auc_score, recall_score
# import matplotlib.pyplot as plt
#
# # Load sample dataset
# df = pd.read_csv('loan_sample.csv', low_memory=False)
#
# # Filter statuses
# target_statuses = ['Fully Paid', 'Charged Off', 'Default']
# df_filtered = df[df['loan_status'].isin(target_statuses)].copy()
#
# # Encode target
# df_filtered['default'] = df_filtered['loan_status'].isin(['Charged Off', 'Default']).astype(int)
#
# # Class distribution code
# counts = df_filtered['default'].value_counts()
# plt.figure(figsize=(6, 4))
# plt.bar(counts.index.astype(str), counts.values, color=['green','red'])
# plt.ylabel('Number of Loans')
# plt.xlabel('Class (0 = non-default, 1 = default)')
# plt.title('Class Distribution')
# plt.show()
#
# for cls in counts.index:
#     print(f"Class {cls}: {counts[cls]} ({percent[cls]:.2f}%)")
#
# # Variable selection code
# selected_vars = [
#     'annual_inc',
#     'application_type',
#     'dti',
#     'home_ownership',
#     'purpose',
#     'default',  # target
#     'issue_d',  # for time-based splitting
# ]
# df_model = df_filtered[selected_vars].copy()
#
# # Numeric variables description code
# df_model.describe()
#
# # Missing values code
# missing_counts = df_model.isna().sum().sort_values(ascending=False)
# total_rows = len(df_model)
#
# missing_vars = missing_counts[missing_counts > 0]
#
# if len(missing_vars) > 0:
#     print("Variables with missing values:")
#     for col, count in missing_vars.items():
#         percentage = (count / total_rows) * 100
#         print(f"{col}: {count} ({percentage:.2f}%)")
# else:
#     print("No missing values found")
#
# # Replace missing values code
# numeric_cols = df_model.select_dtypes(include=['number']).columns
# df_model[numeric_cols] = df_model[numeric_cols].fillna(df_model[numeric_cols].median())
#
# # One hot encoding code
# categorical_cols = ['purpose', 'home_ownership', 'application_type']
# df_model = pd.get_dummies(df_model, columns=categorical_cols, drop_first=True)
#
# # Time-based Train/test split
# df_sorted = df_model.sort_values('issue_d')
#
# split_point = int(0.8 * len(df_sorted))
#
# X_train = df_sorted.iloc[:split_point].drop(['default', 'issue_d'], axis=1)
# y_train = df_sorted.iloc[:split_point]['default']
# X_test = df_sorted.iloc[split_point:].drop(['default', 'issue_d'], axis=1)
# y_test = df_sorted.iloc[split_point:]['default']
#
# # Scaling
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
#
#
# # Train model and make predictions
# model = LogisticRegression() # L2 regularization by default
# model.fit(X_train_scaled, y_train)
# y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]
# y_pred = (y_pred_proba >= 0.5).astype(int)
#
#
# # Calculate recall
# recall_0 = recall_score(y_test, y_pred, pos_label=0)
# recall_1 = recall_score(y_test, y_pred, pos_label=1)
#
# print(f"Class 0 recall: {recall_0:.2f}\n"
#       f"Class 1 recall: {recall_1:.2f}")
#
#
# # AUC and Gini
# auc = roc_auc_score(y_test, y_pred_proba)
# print(f"\nAUC: {auc:.3f}")
#
# gini = 2 * auc - 1
# print(f"Gini coefficient: {gini:.3f}")
#
#
# # ROC plot
# plt.figure(figsize=(6,4))
# # plot ROC curve
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
# plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {auc:.3f})')
#
# # plot KS point
# ks_index = (tpr - fpr).argmax()
# plt.scatter(fpr[ks_index], tpr[ks_index], color='red', s=30, label='KS point', zorder=5)
#
# plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')  # random classifier line
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate (FPR)')
# plt.ylabel('True Positive Rate (TPR)')
# plt.title('ROC Curve')
# plt.legend(loc="lower right")
# plt.grid(True)
# plt.show()
#
#
# # KS point
# ks = max(tpr - fpr)
# print(f'KS: {ks:.3f}')
#
#
# # PSI code details
# # Predicted probabilities for the training set
# y_pred_proba_train = model.predict_proba(X_train_scaled)[:, 1]
#
# n_bins = 10
# bin_edges = np.linspace(0, 1, n_bins + 1)
#
# df_PSI_test = pd.DataFrame({'y_pred_proba': y_pred_proba})
#
# df_PSI_test['bin'] = pd.cut(df_PSI_test['y_pred_proba'], bins=bin_edges, include_lowest=True)
#
# df_test_bins = (
#     df_PSI_test.groupby('bin')
#     .agg(count=('y_pred_proba', 'count'))
#     .reset_index()
# )
#
# df_test_bins['fraction_test'] = df_test_bins['count'] / df_test_bins['count'].sum()
#
# df_PSI_train = pd.DataFrame({'y_pred_proba_train': y_pred_proba_train})
#
# df_PSI_train['bin'] = pd.cut(df_PSI_train['y_pred_proba_train'], bins=bin_edges, include_lowest=True)
#
# df_train_bins = (
#     df_PSI_train.groupby('bin')
#     .agg(count=('y_pred_proba_train', 'count'))
#     .reset_index()
# )
#
# df_train_bins['fraction_train'] = df_train_bins['count'] / df_train_bins['count'].sum()
#
# def calculate_psi(train_frac, test_frac):
#     """
#     train_frac: array of fractions per bin in the baseline population
#     test_frac: array of fractions per bin in the new population
#     """
#     epsilon = 1e-8  # to avoid division by zero
#     psi_values = (train_frac - test_frac) * np.log((train_frac + epsilon) / (test_frac + epsilon))
#     return np.sum(psi_values)
#
# psi = calculate_psi(df_train_bins['fraction_train'], df_test_bins['fraction_test'])
# print(f'PSI ({n_bins} bins): {psi:.3f}')
#
#
# # PSI plot code
# plt.figure(figsize=(6,4))
# x_mid = df_test_bins['bin'].apply(lambda x: x.mid).to_numpy()
# plt.plot(x_mid, df_train_bins['fraction_train'].to_numpy(), label='Train', marker='o')
# plt.plot(x_mid, df_test_bins['fraction_test'].to_numpy(), label='Test', marker='o')
#
# plt.xticks(rotation=45)
# plt.xticks(np.arange(0, 1.01, 0.1))  # ticks at 0.0, 0.1, 0.2, ..., 1.0
# plt.xlabel("Probability bin")
# plt.ylabel("Fraction of samples")
# plt.title("Distribution of predicted probabilities (Train vs Test)")
# plt.legend()
# plt.tight_layout()
# plt.show()
#
# # Calibration plot code
# df_calibration = pd.DataFrame({
#     'y_test': y_test,
#     'y_pred_proba': y_pred_proba
# })
#
# n_bins_cali = 10
# bin_edges = np.linspace(0, 1, n_bins_cali + 1)
#
# df_calibration["bin"] = pd.cut(df_calibration['y_pred_proba'], bins=bin_edges, include_lowest=True)
# calibration_table = df_calibration.groupby('bin').agg(
#     avg_pred=('y_pred_proba', 'mean'),          # Average predicted PD in the bin
#     obs_default_rate=('y_test', 'mean'),        # Fraction of defaults in the bin
# ).reset_index() # make the bins a column instead of index, and use standard index
#
# plt.figure(figsize=(6,4))
# plt.plot([0,1], [0,1], 'k--', label='Perfect calibration')
# plt.plot(calibration_table['avg_pred'].to_numpy(), calibration_table['obs_default_rate'].to_numpy(), marker='o', label='Model')
# plt.xlabel('Average Predicted PD')
# plt.ylabel('Observed Default Rate')
# plt.title('Calibration Plot')
# plt.legend()
# plt.show()
#
# # feature importance code
# feature_importance = pd.DataFrame({
#     'Feature': X_train.columns,
#     'Coefficient': model.coef_[0].round(3)
# }).sort_values('Coefficient', key=abs, ascending=False)
# top_n_features = 5
# feature_importance.head(top_n_features)
#
# top_features = feature_importance.head(top_n_features)
# top_features.style.hide(axis='index')
